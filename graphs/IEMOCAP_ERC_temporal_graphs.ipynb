# %%
import pickle
data_path = '../IEMOCAP_DATA/IEMOCAP_features.pkl'

# users should use this instructor to load pkl dataset. 
videoIDs, videoSpeakers, videoLabels, videoText,\
    videoAudio, videoVisual, videoSentence, trainVid,\
        testVid = pickle.load(open(data_path, 'rb'), encoding='latin1')

# %%
print(len(videoIDs))

print(videoIDs['Ses03M_impro08b'])

print(len(trainVid))

print(trainVid)

print(len(testVid))

print(testVid)
# Out:
# 151
# ['Ses03M_impro08b_M000', 'Ses03M_impro08b_F001', 'Ses03M_impro08b_M001', 'Ses03M_impro08b_F002', 'Ses03M_impro08b_M002', 'Ses03M_impro08b_F003', 'Ses03M_impro08b_M003', 'Ses03M_impro08b_F004', 'Ses03M_impro08b_M004', 'Ses03M_impro08b_F005', 'Ses03M_impro08b_F006', 'Ses03M_impro08b_F007', 'Ses03M_impro08b_M005', 'Ses03M_impro08b_F008', 'Ses03M_impro08b_M006', 'Ses03M_impro08b_F009', 'Ses03M_impro08b_M007', 'Ses03M_impro08b_F010', 'Ses03M_impro08b_M008', 'Ses03M_impro08b_M009', 'Ses03M_impro08b_F011', 'Ses03M_impro08b_M010', 'Ses03M_impro08b_F012', 'Ses03M_impro08b_M011', 'Ses03M_impro08b_F013', 'Ses03M_impro08b_M012', 'Ses03M_impro08b_F014', 'Ses03M_impro08b_M013', 'Ses03M_impro08b_M014', 'Ses03M_impro08b_F015', 'Ses03M_impro08b_M015', 'Ses03M_impro08b_F016', 'Ses03M_impro08b_M016', 'Ses03M_impro08b_M017', 'Ses03M_impro08b_M018', 'Ses03M_impro08b_M019', 'Ses03M_impro08b_M020', 'Ses03M_impro08b_F021', 'Ses03M_impro08b_M021', 'Ses03M_impro08b_F023', 'Ses03M_impro08b_M022', 'Ses03M_impro08b_F024']
# 120
# ['Ses02F_script01_3', 'Ses03F_script03_1', 'Ses01M_impro03', 'Ses02M_impro07', 'Ses02M_impro08', 'Ses02F_script01_1', 'Ses02M_script02_2', 'Ses03M_impro05b', 'Ses01M_script02_2', 'Ses04F_impro07', 'Ses02M_impro02', 'Ses04F_script01_1', 'Ses02M_impro05', 'Ses03M_impro07', 'Ses03M_script02_2', 'Ses04M_script03_1', 'Ses03F_impro03', 'Ses04F_script01_3', 'Ses02F_script02_1', 'Ses04M_impro02', 'Ses04F_impro08', 'Ses03M_impro02', 'Ses04M_impro08', 'Ses04F_script03_2', 'Ses01F_impro07', 'Ses01F_impro02', 'Ses01M_impro02', 'Ses04F_impro03', 'Ses03M_script02_1', 'Ses04F_impro04', 'Ses02M_script01_3', 'Ses01F_script03_2', 'Ses04F_script03_1', 'Ses04F_script02_2', 'Ses04F_impro02', 'Ses03F_impro06', 'Ses03M_impro04', 'Ses02F_script02_2', 'Ses04F_impro01', 'Ses04F_impro05', 'Ses01M_impro06', 'Ses02F_script03_2', 'Ses04M_script02_1', 'Ses02F_impro08', 'Ses02M_impro03', 'Ses01F_script02_1', 'Ses03M_script03_2', 'Ses01F_script01_1', 'Ses03M_impro01', 'Ses02F_impro07', 'Ses02F_impro05', 'Ses01F_script03_1', 'Ses04M_impro04', 'Ses03F_impro01', 'Ses02M_impro04', 'Ses04M_impro06', 'Ses03M_impro05a', 'Ses04M_script03_2', 'Ses03F_impro08', 'Ses04M_impro07', 'Ses03F_script01_1', 'Ses01F_impro04', 'Ses03F_script02_1', 'Ses01M_script01_3', 'Ses01M_script01_1', 'Ses03F_script03_2', 'Ses01F_script01_3', 'Ses03M_impro03', 'Ses01M_script03_1', 'Ses03M_script01_2', 'Ses01M_impro07', 'Ses03F_script01_2', 'Ses02F_script03_1', 'Ses04M_impro05', 'Ses02F_impro06', 'Ses02M_impro01', 'Ses02M_script01_2', 'Ses03M_script01_1', 'Ses04M_script01_2', 'Ses01F_script01_2', 'Ses04F_impro06', 'Ses03M_impro08b', 'Ses02M_script01_1', 'Ses02M_script03_2', 'Ses04F_script02_1', 'Ses03F_impro02', 'Ses01M_script02_1', 'Ses03M_script01_3', 'Ses04M_impro01', 'Ses02F_script01_2', 'Ses04F_script01_2', 'Ses01F_script02_2', 'Ses01M_impro05', 'Ses02M_script02_1', 'Ses03M_script03_1', 'Ses03F_impro05', 'Ses02F_impro04', 'Ses02M_script03_1', 'Ses01F_impro03', 'Ses03F_impro07', 'Ses01F_impro01', 'Ses02M_impro06', 'Ses04M_impro03', 'Ses02F_impro03', 'Ses03M_impro08a', 'Ses03F_impro04', 'Ses04M_script02_2', 'Ses01M_script03_2', 'Ses01M_impro04', 'Ses01M_impro01', 'Ses01M_script01_2', 'Ses01F_impro06', 'Ses04M_script01_3', 'Ses04M_script01_1', 'Ses02F_impro02', 'Ses01F_impro05', 'Ses03F_script02_2', 'Ses03M_impro06', 'Ses02F_impro01', 'Ses03F_script01_3']
# 31
# ['Ses05F_impro08', 'Ses05M_impro02', 'Ses05F_impro01', 'Ses05F_script01_2', 'Ses05F_impro05', 'Ses05M_script01_2', 'Ses05F_impro04', 'Ses05M_impro08', 'Ses05F_script03_2', 'Ses05F_script02_2', 'Ses05M_impro04', 'Ses05M_script03_2', 'Ses05M_impro05', 'Ses05M_impro03', 'Ses05M_script01_3', 'Ses05F_impro02', 'Ses05F_script02_1', 'Ses05F_impro03', 'Ses05F_impro06', 'Ses05M_script02_2', 'Ses05F_script03_1', 'Ses05M_script03_1', 'Ses05M_script02_1', 'Ses05M_script01_1b', 'Ses05F_script01_3', 'Ses05F_script01_1', 'Ses05M_impro01', 'Ses05F_impro07', 'Ses05M_impro07', 'Ses05M_script01_1', 'Ses05M_impro06']

# %%
import pandas as pd
conversation_dfs_train = {}
conversation_dfs_test = {}
participant_ID_toInt = {'M':1, 'F':0}

for ID in videoIDs:

    utterances = videoSentence[ID]
    emotions = videoLabels[ID]
    speakers = videoSpeakers[ID]
    speakers = [participant_ID_toInt[speaker] for speaker in speakers]
    utterance_IDs = videoIDs[ID]


    df = pd.DataFrame({
    'Utterance': utterances,
    'Speaker': speakers,
    'Emotion': emotions,
    'Utterance_ID': utterance_IDs,
    })
    if ID in trainVid:
        conversation_dfs_train[ID] = df
    else:
        conversation_dfs_test[ID] = df

# %%
conversation_dfs_test['Ses05M_impro08'].head(50)
# Out:
#                                             Utterance  Speaker  Emotion  \
# 0                     D.S.L. Extreme, can I help you?        1        2
# 1   Hi, I need- I need some help.  I've been trans...        0        5
# 2                       This happens every two weeks?        1        2
# 3               Yeah.  That my service just goes out.        0        5
# 4                        You've lost your connection.        1        2
# 5                                               yeah.        0        5
# 6                                               okay.        1        2
# 7   And I'll reset the IP address.  I will do like...        0        5
# 8                                          Hmm.  Mmm.        1        2
# 9   Is not, It it It will work again for like a we...        0        5
# 10               Has somebody tried to pin your site?        1        2
# 11      Uh, yeah.  We've pinned it a couple of times.        0        2
# 12  Okay. Um-  Well, I don't know.  And it consist...        1        2
# 13  Pretty much, yeah - I don't know if it's, like...        0        2
# 14  Well, you know what, does your D.S.L. cable --...        1        2
# 15                                          Hmm. Mmm.        0        2
# 16  Okay.  Does your D.S.L. cable, you know, trave...        1        2
# 17                                              yeah.        0        2
# 18  It goes- It goes, like, through doorways.  But...        0        2
# 19  Okay.  Is it being- Is it being compressed bet...        1        2
# 20  Yeah. That can be- That can create a bad conne...        1        2
# 21  Well, I- I can check that.  Is there anything ...        0        2
# 22  Yeah, well, absolutely.  What we can -- let's ...        1        2
# 23                                            Uh huh.        0        2
# 24           Okay, And uh- go ahead and click on run.        1        2
# 25                                         All right.        0        2
# 26  Okay.  We're gonna get your -- a little black ...        1        2
# 27                                  Yeah, I see that.        0        2
# 28  Okay Uh- You've got your C calling, go ahead a...        1        2
# 29                                              Okay.        0        2
# 30                                     And hit enter.        1        2
# 31                                              Okay.        0        2
# 32             Okay?  Can you tell me what that says?        1        2
# 33  Uh, it it's like a bunch of different letter a...        0        2
# 34  Okay Okay, And Um- letters and numbers and stu...        1        2
# 35                                      Uh huh, Okay.        0        2
# 36         Okay?  Does it list your IP address there?        1        2
# 37      Uh, yeah looks -- no, no.  It's set to zeros.        0        2
# 38  It's set to zeros.  Okay, maybe that's our pro...        1        2
# 39  Well, if it does happen again, let me give you...        1        2
# 40  Of course.  we seriously- Yeah, I mean, obviou...        1        2
# 41  Oh, my God.  I can't even tell you how much of...        0        0
# 42                           I completely understand.        1        2
# 43                               It's so frustrating.        0        5
# 44  Absolutely. And I just don't want that to happ...        1        2
# 45   Absolutely.  It's a new service we are offering.        1        2
# 46               Yeah, accountability.  It's awesome.        0        0
# 47  Uh huh Uh huh We want you to be happy.  You're...        1        2
# 48  Wow.  You know I was thinking about changing i...        0        0
# 49  Great.  Well, that makes me very happy.  That ...        1        0
#
#            Utterance_ID
# 0   Ses05M_impro08_M000
# 1   Ses05M_impro08_F000
# 2   Ses05M_impro08_M001
# 3   Ses05M_impro08_F001
# 4   Ses05M_impro08_M002
# 5   Ses05M_impro08_F002
# 6   Ses05M_impro08_M003
# 7   Ses05M_impro08_F003
# 8   Ses05M_impro08_M004
# 9   Ses05M_impro08_F004
# 10  Ses05M_impro08_M005
# 11  Ses05M_impro08_F005
# 12  Ses05M_impro08_M006
# 13  Ses05M_impro08_F006
# 14  Ses05M_impro08_M007
# 15  Ses05M_impro08_F007
# 16  Ses05M_impro08_M008
# 17  Ses05M_impro08_F008
# 18  Ses05M_impro08_F009
# 19  Ses05M_impro08_M009
# 20  Ses05M_impro08_M010
# 21  Ses05M_impro08_F011
# 22  Ses05M_impro08_M011
# 23  Ses05M_impro08_F012
# 24  Ses05M_impro08_M012
# 25  Ses05M_impro08_F013
# 26  Ses05M_impro08_M013
# 27  Ses05M_impro08_F014
# 28  Ses05M_impro08_M014
# 29  Ses05M_impro08_F015
# 30  Ses05M_impro08_M015
# 31  Ses05M_impro08_F016
# 32  Ses05M_impro08_M016
# 33  Ses05M_impro08_F017
# 34  Ses05M_impro08_M017
# 35  Ses05M_impro08_F018
# 36  Ses05M_impro08_M018
# 37  Ses05M_impro08_F019
# 38  Ses05M_impro08_M019
# 39  Ses05M_impro08_M020
# 40  Ses05M_impro08_M021
# 41  Ses05M_impro08_F022
# 42  Ses05M_impro08_M022
# 43  Ses05M_impro08_F023
# 44  Ses05M_impro08_M023
# 45  Ses05M_impro08_M024
# 46  Ses05M_impro08_F025
# 47  Ses05M_impro08_M025
# 48  Ses05M_impro08_F026
# 49  Ses05M_impro08_M026

# %%
print(f'Number of Conversations in the Training Set: ', len(conversation_dfs_train))
print(f'Number of Utterances in the Training Set: ', sum(len(value) for value in conversation_dfs_train.values()))
print(f'Number of Conversations in the Testing Set: ', len(conversation_dfs_test))
print(f'Number of Utterances in the Testing Set: ', sum(len(value) for value in conversation_dfs_test.values()))
# Out:
# Number of Conversations in the Training Set:  120
# Number of Utterances in the Training Set:  5810
# Number of Conversations in the Testing Set:  31
# Number of Utterances in the Testing Set:  1623

# %%
from transformers import BertTokenizer, BertModel
import torch

# Load pre-trained BERT model and tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained('bert-base-uncased')

# Set the model to evaluation mode to prevent updates to weights
model.eval()

def embedding_func(speech_line):
    """
    Generate BERT embedding for a given speech line.

    Parameters:
    - speech_line: A string representing a single line of speech.

    Returns:
    - A 768-dimensional BERT embedding as a list of floats.
    """
    # Tokenize the input text and convert to PyTorch tensors
    inputs = tokenizer(speech_line, return_tensors='pt', truncation=True, padding=True, max_length=512)

    # Get the model outputs (embedding) from the last hidden layer
    with torch.no_grad():
        outputs = model(**inputs)
    
    # The embeddings are in 'last_hidden_state', take the [CLS] token as the sentence-level embedding
    cls_embedding = outputs.last_hidden_state[:, 0, :]  # [CLS] token embedding
    
    # Convert to a Python list (detaching from the computation graph)
    embedding = cls_embedding.squeeze().tolist()

    return embedding

# %%
def create_dialogue_graphs(dfs):

    dialogue_graphs = []

    # Create a placeholder for null embeddings (assuming embeddings are vectors)
    null_embedding = [0] * 768  

    # To iterate over each group
    for dialogue in dfs.values():

        participants = dialogue['Speaker'].unique()
        G = []

        for index, row in dialogue.iterrows():
        
            G_i = {'X': {}, 'Y': 'Uninitialized'}
            G_i['Y'] = row['Emotion']
            speaker = row['Speaker']

            # Initialize speaker nodes for each timestamp
            for p in participants:
                if p == speaker:
                    speaker_embedding = embedding_func(row['Utterance'])
                    speaker_edges = [f'{node}_{index}' for node in participants if node != speaker]
                    G_i['X'][f'{p}_{index}'] = {'embedding': speaker_embedding, 'edges': speaker_edges}
                else:    
                    G_i['X'][f'{p}_{index}'] = {'embedding': null_embedding, 'edges': []}

            G.append(G_i)

        dialogue_graphs.append(G)


    return dialogue_graphs

# %%
IEMOCAP_train_dialogue_graphs = create_dialogue_graphs(conversation_dfs_train)
IEMOCAP_test_dialogue_graphs = create_dialogue_graphs(conversation_dfs_test)

# %%
import pickle

with open('data/ERC/IEMOCAP/train_dialogue_graphs.pkl', 'wb') as f:
    pickle.dump(IEMOCAP_train_dialogue_graphs, f)

with open('data/ERC/IEMOCAP/test_dialogue_graphs.pkl', 'wb') as f:
    pickle.dump(IEMOCAP_test_dialogue_graphs, f)
